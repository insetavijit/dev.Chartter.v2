# %%
import pandas as pd

# Load parquet file
df = pd.read_parquet("./src/enterprise_trading_results.parquet")

# %%
df
# Out:
#                          Open      High       Low     Close  Volume  \
# datetime
# 2024-10-01 00:00:00  2635.660  2635.899  2635.290  2635.519      89
# 2024-10-01 00:01:00  2635.535  2635.849  2635.463  2635.687      72
# 2024-10-01 00:02:00  2635.682  2636.025  2635.382  2635.975      86
# 2024-10-01 00:03:00  2635.977  2636.152  2635.616  2636.097      89
# 2024-10-01 00:04:00  2636.081  2636.200  2635.810  2636.052      72
# ...                       ...       ...       ...       ...     ...
# 2024-10-01 23:56:00  2660.561  2660.595  2660.361  2660.539      47
# 2024-10-01 23:57:00  2660.497  2660.553  2660.353  2660.553      44
# 2024-10-01 23:58:00  2660.568  2660.682  2660.436  2660.508      48
# 2024-10-01 23:59:00  2660.514  2660.514  2660.359  2660.361      35
# 2024-10-02 00:00:00  2660.390  2660.663  2659.699  2659.985     138
#
#                         RSI_14     EMA_15  RSI_14_crossed_up_EMA_15        SL  \
# datetime
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


# Example 1: Distribution of PnL (if there's a column for profit/loss)
sns.histplot(df['Open'], bins=30, kde=True)
plt.title("PnL Distribution")
plt.show()
